# %%
import pandas as pd
import numpy as np
import re
import string
import unicodedata
import plotly_express as px
import plotly.io as pio
from sklearn import preprocessing
import pandas_profiling
import datetime
# %matplotlib inline
import matplotlib.style
import matplotlib as mpl
import matplotlib.pyplot as plt 
from sklearn import preprocessing
import warnings
import math
import plotly.express as px
import statsmodels
import scipy
import sklearn
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders
from statsmodels.tsa.statespace.sarimax import SARIMAX


warnings.filterwarnings("ignore")

# scipy
print('scipy: %s' % scipy.__version__)
# numpy
print('numpy: %s' % np.__version__)
# matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# pandas
print('pandas: %s' % pd.__version__)
# scikit-learn
print('sklearn: %s' % sklearn.__version__)
# statsmodels
print('statsmodels: %s' % statsmodels.__version__)
#print('unicodedata: %s' % unicodedata.__version__)
# Out:
# scipy: 1.4.1
# numpy: 1.18.2
# matplotlib: 3.2.1
# pandas: 1.0.3
# sklearn: 0.22.2.post1
# statsmodels: 0.11.1

# %%
#verificar feriados 
def isHoliday(dia,mes):
    if dia == 1:
        if mes == 1 or mes ==5:
            return(True)
    if (dia ==2 or dia==15) and mes==11:
        return(True)
    if (dia ==7 or dia==20) and mes == 9:
        return(True)
    if mes == 4 and dia==21:
        return(True)    
    if mes==10 and (dia==12):
        return(True)
    if mes==12 and (dia ==25 or dia ==24):
        return(True)
    if mes==12 and dia==31:
        return(True)
    return(False)   

def AdjustFeriado(x):
    #print(x)
    if x['Feriado'] == 0 or x['Feriado'] == 1:
        return(x['Feriado'])
       # print('else')
       # print(x['Feriado'] >=0)
    else:
        dia = x['judgmentDate'].day
        mes = x['judgmentDate'].month 
        feriado = 0 if isHoliday(dia,mes) == True else 1
        return(feriado)
    
def AdjustWeekDay(x):    
    if x['weekDay'] > 0:
        return(x['weekDay'])
    else:
        return(x['judgmentDate'].weekday())        
    
def AdjustWeekType(x):    
    if x['weekType'] > 0:
        return(x['weekType'])
    else:
        weekType = 1 if x['judgmentDate'].weekday() <5 else 0
        return(weekType)

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
#carrega
df_count_day_type = pd.read_csv('./data_joao/df_count_day_type_modificado.csv',sep=",")#,parse_dates=['judgmentDate'])
df_count_week_day_type = pd.read_csv('./data_joao/df_count_week_day_type_modificado.csv',sep=",")
df_count_year_month_type = pd.read_csv('./data_joao/df_count_year_month_type_modificado.csv',sep=",")

#cria indice
df_count_day_type.index = pd.to_datetime(df_count_day_type['judgmentDate'])
df_count_year_month_type.index = pd.to_datetime(df_count_year_month_type['yearMonth'])

#deleta colunas que sobraram da importacao e da criacao do indice
del df_count_day_type['Unnamed: 0']
del df_count_week_day_type['Unnamed: 0']
del df_count_year_month_type['Unnamed: 0']
del df_count_day_type['judgmentDate']
del df_count_year_month_type['yearMonth']

#calcula o total do dia
df_count_day_type['total'] = df_count_day_type.groupby(['judgmentDate'])['count'].agg('sum')
#salva as informacoes que nao serao pivotadas
ref = df_count_day_type[['weekDay','weekType','Feriado','total']]
#realiza o pivot
df_count_day_typeGRP = df_count_day_type.pivot(columns='type', values='count').fillna(0)

#transforma tudo pra int (count)
for i in df_count_day_typeGRP.columns:    
        df_count_day_typeGRP[i] = df_count_day_typeGRP[i].astype(int)
        
#faz o merge com as que foram salvas antes do pivot        
df_count_day_typeGRP = pd.merge(df_count_day_typeGRP,ref,on='judgmentDate',how='left')
df_count_day_typeGRP = df_count_day_typeGRP.fillna(0)
df_count_day_typeGRP = df_count_day_typeGRP.sort_values(by='judgmentDate').drop_duplicates()

#remove duplicadas e nulas pra fazer a frequencia diaria
df_count_day_typeGRP = df_count_day_typeGRP.sort_values(by='judgmentDate')
df_count_day_typeGRP = df_count_day_typeGRP.drop_duplicates()
df_count_day_typeGRP = df_count_day_typeGRP.dropna()


df_count_day_typeGRP.sort_values(by='judgmentDate')
df_count_day_typeGRP['Feriado'] = df_count_day_typeGRP['Feriado'].apply( lambda x: 0 if x==True else 1)
df_count_day_typeGRP['weekType'] = pd.get_dummies(df_count_day_typeGRP['weekType'])
df_count_day_typeGRP = df_count_day_typeGRP.asfreq('D') #precisa pois abaixo seto os que faltam

#reseta o indice agora com todos os dias inclusive vazios e seta as informaçoes das datas novas (sem dados)
df_count_day_typeGRP = df_count_day_typeGRP.reset_index()    
df_count_day_typeGRP['Feriado'] = df_count_day_typeGRP.apply(AdjustFeriado,axis=1)
df_count_day_typeGRP['weekDay'] = df_count_day_typeGRP.apply(AdjustWeekDay,axis=1)
df_count_day_typeGRP['weekType'] = df_count_day_typeGRP.apply(AdjustWeekType,axis=1)

#volta ao estado normal (com indice e frequencia)
df_count_day_typeGRP.index = df_count_day_typeGRP['judgmentDate']
del df_count_day_typeGRP['judgmentDate']
df_count_day_typeGRP = df_count_day_typeGRP.asfreq('D')

#seta para zerado as datas que nao existiam antes 
df_count_day_typeGRP = df_count_day_typeGRP.fillna(0)

for i in df_count_day_typeGRP.columns:    
        df_count_day_typeGRP[i] = df_count_day_typeGRP[i].astype(int)

# %%
df_count_day_typeGRP = df_count_day_typeGRP['2014-01-01':]
df_count_day_typeGRP.head(3)
df = df_count_day_typeGRP

field = 'total'

# %%
#df_count_day_typeGRP['total']['2017-01-01':].plot(figsize=(18,8))

ax = df[field]['2013-01-01':'2017-02-01'].plot(figsize=(50,22))

for dia in df.query('Feriado==0').index:    
    ax.axvline(x=dia,color='black',alpha=0.5)
    
for dia in df.query('weekType==0').index:    
    ax.axvline(x=dia,color='red',alpha=0.5)
    
for dia in df.query('weekDay==3').index:    
    ax.axvline(x=dia,color='green',alpha=0.5)

# %%
summ = auto_arima(df[field],seasonal=True,m=7)

# %%
arima_order = summ.order
arima_seasonal_order = summ.seasonal_order
titleTest = "Arima({}) - ({})".format(arima_order,arima_seasonal_order)

# %%
train = df[:'2016-08-01']
test = df['2016-08-01':]

print(train[field].count(),test[field].count())
# Out:
# 944 516

# %%
model = SARIMAX(train[field],order=arima_order,seasonal_order=arima_seasonal_order)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             total   No. Observations:                  944
# Model:             SARIMAX(5, 0, 2)x(2, 0, 2, 7)   Log Likelihood               -7796.190
# Date:                           Wed, 06 May 2020   AIC                          15616.381
# Time:                                   01:07:57   BIC                          15674.582
# Sample:                               01-01-2014   HQIC                         15638.563
#                                     - 08-01-2016
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1645      0.078     -2.097      0.036      -0.318      -0.011
# ar.L2         -0.5619      0.079     -7.105      0.000      -0.717      -0.407
# ar.L3          0.4252      0.094      4.528      0.000       0.241       0.609
# ar.L4         -0.0674      0.076     -0.892      0.372      -0.216       0.081
# ar.L5         -0.0415      0.098     -0.422      0.673      -0.234       0.151
# ma.L1          0.6560      0.069      9.571      0.000       0.522       0.790
# ma.L2          0.9223      0.071     13.034      0.000       0.784       1.061
# ar.S.L7        0.2652      0.189      1.402      0.161      -0.106       0.636
# ar.S.L14       0.7324      0.189      3.876      0.000       0.362       1.103
# ma.S.L7       -0.2921      0.214     -1.365      0.172      -0.711       0.127
# ma.S.L14      -0.6319      0.204     -3.090      0.002      -1.033      -0.231
# sigma2      1.206e+06    3.4e-07   3.55e+12      0.000    1.21e+06    1.21e+06
# ===================================================================================
# Ljung-Box (Q):                       59.30   Jarque-Bera (JB):               404.30
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             0.60
# Prob(H) (two-sided):                  0.40   Kurtosis:                         5.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.96e+28. Standard errors may be unstable.
# """

# %%
start=len(train)
end=len(train)+len(test)-1
predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename(titleTest + "  - predictions" )

# %%
for i in range(len(predictions)):
    print(f"predicted={predictions[i]:<11.10}, expected={test[field][i]}")
# Out:
# predicted=1089.389897, expected=486
# predicted=2041.231688, expected=336
# predicted=2341.842739, expected=1137
# predicted=658.1311531, expected=940
# predicted=-89.09336321, expected=859
# predicted=66.90674769, expected=75
# predicted=575.4621428, expected=0
# predicted=1503.745363, expected=657
# predicted=2688.91349 , expected=462
# predicted=2704.161853, expected=3340
# predicted=742.7983304, expected=3233
# predicted=-12.36177222, expected=806
# predicted=81.75012667, expected=7
# predicted=493.7246128, expected=0
# predicted=1255.64126 , expected=1304
# predicted=2358.482587, expected=1004
# predicted=2363.565909, expected=2513
# predicted=629.2073464, expected=2399
# predicted=38.84125322, expected=772
# predicted=39.20518946, expected=7
# predicted=474.4334831, expected=60
# predicted=1516.636453, expected=827
# predicted=2606.395925, expected=2922
# predicted=2523.527755, expected=3453
# predicted=759.6367417, expected=4842
# predicted=42.90563811, expected=1694
# predicted=-3.790540532, expected=0
# predicted=502.0683201, expected=0
# predicted=1378.867781, expected=530
# predicted=2364.46572 , expected=2451
# predicted=2386.467605, expected=5773
# predicted=721.1946584, expected=2516
# predicted=10.42676267, expected=722
# predicted=-5.144687577, expected=0
# predicted=530.7511902, expected=0
# predicted=1470.691504, expected=1377
# predicted=2494.168483, expected=525
# predicted=2515.811679, expected=4
# predicted=760.8374149, expected=1397
# predicted=-6.981551537, expected=754
# predicted=13.03405537, expected=107
# predicted=533.7724782, expected=18
# predicted=1366.167155, expected=934
# predicted=2393.884766, expected=333
# predicted=2445.009886, expected=3256
# predicted=707.7817497, expected=2572
# predicted=-5.915587695, expected=668
# predicted=28.20458672, expected=0
# predicted=520.6496656, expected=0
# predicted=1420.19026 , expected=268
# predicted=2483.841128, expected=0
# predicted=2492.440114, expected=1289
# predicted=723.3733993, expected=4285
# predicted=7.183868323, expected=652
# predicted=26.79902242, expected=14
# predicted=509.3931725, expected=0
# predicted=1382.15041 , expected=984
# predicted=2426.161263, expected=3872
# predicted=2436.852445, expected=5679
# predicted=707.6129632, expected=4875
# predicted=12.82951988, expected=1084
# predicted=19.25781059, expected=21
# predicted=508.521031 , expected=23
# predicted=1419.964341, expected=1061
# predicted=2460.138192, expected=600
# predicted=2461.060314, expected=2294
# predicted=727.0087861, expected=2381
# predicted=11.44276491, expected=476
# predicted=14.01452532, expected=13
# predicted=512.9963411, expected=11
# predicted=1394.94441 , expected=926
# predicted=2420.202139, expected=1095
# predicted=2438.081587, expected=5
# predicted=718.6759805, expected=2481
# predicted=6.267130682, expected=1450
# predicted=15.21963548, expected=0
# predicted=515.9276502, expected=82
# predicted=1406.908744, expected=656
# predicted=2438.789924, expected=353
# predicted=2454.961558, expected=2813
# predicted=723.0317094, expected=2699
# predicted=4.529118896, expected=305
# predicted=18.20325231, expected=237
# predicted=514.766928 , expected=14
# predicted=1389.533314, expected=480
# predicted=2420.805275, expected=3388
# predicted=2440.131621, expected=5752
# predicted=714.0668623, expected=5602
# predicted=5.390448923, expected=1262
# predicted=19.90544825, expected=216
# predicted=511.9240775, expected=0
# predicted=1396.990689, expected=1320
# predicted=2431.572306, expected=368
# predicted=2444.185572, expected=14
# predicted=716.2382958, expected=1130
# predicted=7.371030858, expected=766
# predicted=19.15329251, expected=36
# predicted=509.9705322, expected=10
# predicted=1389.580582, expected=1597
# predicted=2419.20138 , expected=300
# predicted=2432.815222, expected=3408
# predicted=713.2467466, expected=3569
# predicted=7.839905892, expected=1220
# predicted=17.95493908, expected=0
# predicted=509.5930624, expected=9
# predicted=1393.545264, expected=962
# predicted=2421.447977, expected=19
# predicted=2434.019694, expected=978
# predicted=715.3061199, expected=1523
# predicted=7.377702188, expected=851
# predicted=17.38335044, expected=62
# predicted=509.7084694, expected=55
# predicted=1387.728428, expected=1435
# predicted=2412.506407, expected=607
# predicted=2427.664218, expected=3424
# predicted=712.9212136, expected=4643
# predicted=6.617543566, expected=1979
# predicted=17.72607131, expected=0
# predicted=509.3819331, expected=0
# predicted=1387.89624 , expected=702
# predicted=2412.702862, expected=2708
# predicted=2427.29421 , expected=5565
# predicted=712.6487822, expected=2209
# predicted=6.498886769, expected=1177
# predicted=18.14582537, expected=27
# predicted=508.4643276, expected=0
# predicted=1383.649691, expected=434
# predicted=2407.062869, expected=3903
# predicted=2421.960573, expected=2071
# predicted=710.4615671, expected=9
# predicted=6.702022653, expected=687
# predicted=18.28146648, expected=0
# predicted=507.4214542, expected=0
# predicted=1383.251618, expected=2459
# predicted=2405.792267, expected=3625
# predicted=2419.666196, expected=5249
# predicted=710.0412598, expected=6413
# predicted=6.969126306, expected=1699
# predicted=18.08404676, expected=28
# predicted=506.5836125, expected=47
# predicted=1380.450315, expected=1656
# predicted=2400.929159, expected=14
# predicted=2415.054781, expected=15
# predicted=708.7572713, expected=16
# predicted=6.971741072, expected=39
# predicted=17.89378556, expected=0
# predicted=505.9641406, expected=6
# predicted=1379.371846, expected=4
# predicted=2398.406359, expected=0
# predicted=2412.407126, expected=0
# predicted=708.2034726, expected=0
# predicted=6.867985418, expected=0
# predicted=17.82588582, expected=0
# predicted=505.3694919, expected=0
# predicted=1376.788067, expected=0
# predicted=2394.183612, expected=0
# predicted=2408.546554, expected=0
# predicted=706.9535074, expected=0
# predicted=6.758530882, expected=0
# predicted=17.8765213 , expected=0
# predicted=504.6867524, expected=4
# predicted=1375.174202, expected=121
# predicted=2391.380067, expected=314
# predicted=2405.594017, expected=196
# predicted=706.0598555, expected=389
# predicted=6.75551888 , expected=227
# predicted=17.91052516, expected=0
# predicted=503.9272317, expected=0
# predicted=1372.891455, expected=221
# predicted=2387.64768 , expected=313
# predicted=2401.875774, expected=366
# predicted=704.8895877, expected=151
# predicted=6.785632018, expected=345
# predicted=17.89394913, expected=24
# predicted=503.1690818, expected=0
# predicted=1371.201664, expected=720
# predicted=2384.587178, expected=219
# predicted=2398.651064, expected=823
# predicted=703.9950877, expected=1715
# predicted=6.811093445, expected=201
# predicted=17.83636693, expected=4
# predicted=502.4493472, expected=44
# predicted=1369.126248, expected=888
# predicted=2380.976222, expected=1340
# predicted=2395.079051, expected=1278
# predicted=702.9564403, expected=6
# predicted=6.79466596 , expected=133
# predicted=17.79038844, expected=0
# predicted=501.7576859, expected=0
# predicted=1367.316591, expected=871
# predicted=2377.743108, expected=1036
# predicted=2391.814298, expected=1173
# predicted=702.0257031, expected=1029
# predicted=6.768870659, expected=533
# predicted=17.76471017, expected=0
# predicted=501.063323 , expected=8
# predicted=1365.279092, expected=320
# predicted=2374.253218, expected=846
# predicted=2388.3583  , expected=1198
# predicted=700.9889354, expected=4003
# predicted=6.747307792, expected=179
# predicted=17.7528389 , expected=0
# predicted=500.3547606, expected=0
# predicted=1363.400087, expected=654
# predicted=2370.985767, expected=3466
# predicted=2385.044701, expected=5580
# predicted=700.0132037, expected=4441
# predicted=6.741926939, expected=305
# predicted=17.73469112, expected=0
# predicted=499.6380986, expected=0
# predicted=1361.420526, expected=46
# predicted=2367.574117, expected=77
# predicted=2381.617389, expected=1234
# predicted=698.9978885, expected=454
# predicted=6.73877575 , expected=397
# predicted=17.70870145, expected=23
# predicted=498.9251733, expected=21
# predicted=1359.533663, expected=639
# predicted=2364.269968, expected=1831
# predicted=2378.273438, expected=2392
# predicted=698.0258892, expected=3616
# predicted=6.733186384, expected=1386
# predicted=17.67830732, expected=17
# predicted=498.2192602, expected=0
# predicted=1357.587164, expected=583
# predicted=2360.885324, expected=313
# predicted=2374.88035 , expected=2938
# predicted=697.0309132, expected=2013
# predicted=6.721491369, expected=448
# predicted=17.65103127, expected=75
# predicted=497.5172811, expected=0
# predicted=1355.68407 , expected=577
# predicted=2357.564839, expected=528
# predicted=2371.538384, expected=2078
# predicted=696.0531959, expected=3691
# predicted=6.709518959, expected=670
# predicted=17.62676809, expected=24
# predicted=496.8147828, expected=5
# predicted=1353.748634, expected=792
# predicted=2354.208642, expected=4193
# predicted=2368.169716, expected=6166
# predicted=695.060581 , expected=5821
# predicted=6.698775246, expected=1427
# predicted=17.60389588, expected=0
# predicted=496.1109658, expected=0
# predicted=1351.840842, expected=556
# predicted=2350.890522, expected=668
# predicted=2364.826976, expected=1271
# predicted=694.079301 , expected=1877
# predicted=6.690316755, expected=1600
# predicted=17.57965039, expected=0
# predicted=495.4072536, expected=0
# predicted=1349.9197  , expected=736
# predicted=2347.553443, expected=572
# predicted=2361.470873, expected=3324
# predicted=693.0932428, expected=1305
# predicted=6.681762798, expected=67
# predicted=17.55434636, expected=16
# predicted=494.7052811, expected=19
# predicted=1348.014923, expected=482
# predicted=2344.237027, expected=365
# predicted=2358.132089, expected=2262
# predicted=692.1148922, expected=2082
# predicted=6.672670195, expected=102
# predicted=17.52869677, expected=11
# predicted=494.005172 , expected=0
# predicted=1346.102908, expected=761
# predicted=2340.912275, expected=2820
# predicted=2354.789701, expected=5125
# predicted=691.1338904, expected=5438
# predicted=6.662764068, expected=500
# predicted=17.50369715, expected=51
# predicted=493.3063008, expected=112
# predicted=1344.199953, expected=16
# predicted=2337.601644, expected=460
# predicted=2351.459109, expected=620
# predicted=690.1566913, expected=1144
# predicted=6.65299798 , expected=1020
# predicted=17.47912238, expected=0
# predicted=492.6080791, expected=0
# predicted=1342.29438 , expected=350
# predicted=2334.289404, expected=633
# predicted=2348.128213, expected=3227
# predicted=689.178435 , expected=1899
# predicted=6.643481811, expected=279
# predicted=17.45467446, expected=7
# predicted=491.9105272, expected=0
# predicted=1340.39546 , expected=515
# predicted=2330.986946, expected=470
# predicted=2344.805322, expected=2301
# predicted=688.2031988, expected=2459
# predicted=6.634273719, expected=380
# predicted=17.43000245, expected=8
# predicted=491.213906 , expected=0
# predicted=1338.496709, expected=851
# predicted=2327.685423, expected=130
# predicted=2341.48438 , expected=3556
# predicted=687.2283931, expected=5085
# predicted=6.624998405, expected=1376
# predicted=17.40523139, expected=35
# predicted=490.518419 , expected=6
# predicted=1336.602714, expected=520
# predicted=2324.391065, expected=3931
# predicted=2338.17014 , expected=5070
# predicted=686.2559096, expected=643
# predicted=6.61563944 , expected=843
# predicted=17.38048073, expected=0
# predicted=489.8240303, expected=68
# predicted=1334.709828, expected=711
# predicted=2321.099381, expected=332
# predicted=2334.859291, expected=2179
# predicted=685.2841429, expected=1901
# predicted=6.6061911  , expected=382
# predicted=17.35587111, expected=0
# predicted=489.130632 , expected=48
# predicted=1332.820624, expected=312
# predicted=2317.813841, expected=1243
# predicted=2331.554204, expected=1997
# predicted=684.3141279, expected=79
# predicted=6.596798663, expected=253
# predicted=17.33134045, expected=0
# predicted=488.4381532, expected=0
# predicted=1330.933289, expected=973
# predicted=2314.531967, expected=817
# predicted=2328.253   , expected=1096
# predicted=683.3451231, expected=2928
# predicted=6.587457729, expected=474
# predicted=17.30684249, expected=0
# predicted=487.7466156, expected=10
# predicted=1329.049249, expected=512
# predicted=2311.255516, expected=3058
# predicted=2324.956985, expected=4988
# predicted=682.3777556, expected=5680
# predicted=6.578164833, expected=1942
# predicted=17.28233682, expected=41
# predicted=487.0560597, expected=16
# predicted=1327.167479, expected=598
# predicted=2307.983116, expected=365
# predicted=2321.665218, expected=1465
# predicted=681.4116082, expected=1061
# predicted=6.568864567, expected=950
# predicted=17.25785217, expected=0
# predicted=486.3665067, expected=87
# predicted=1325.288686, expected=709
# predicted=2304.71574 , expected=245
# predicted=2318.378427, expected=2832
# predicted=680.4469685, expected=3918
# predicted=6.559562901, expected=664
# predicted=17.23340573, expected=3
# predicted=485.677943 , expected=13
# predicted=1323.412306, expected=662
# predicted=2301.452686, expected=283
# predicted=2315.096085, expected=1394
# predicted=679.4835881, expected=3414
# predicted=6.550262966, expected=407
# predicted=17.20901048, expected=0
# predicted=484.9903511, expected=14
# predicted=1321.538742, expected=470
# predicted=2298.194484, expected=2243
# predicted=2311.818553, expected=5780
# predicted=678.5216313, expected=4022
# predicted=6.540985542, expected=1353
# predicted=17.18465363, expected=0
# predicted=484.3037227, expected=0
# predicted=1319.667707, expected=504
# predicted=2294.940739, expected=242
# predicted=2308.545537, expected=759
# predicted=677.5609825, expected=1441
# predicted=6.531726617, expected=307
# predicted=17.16032893, expected=5
# predicted=483.6180622, expected=11
# predicted=1317.79942 , expected=937
# predicted=2291.691721, expected=262
# predicted=2305.277235, expected=2252
# predicted=676.6017363, expected=2190
# predicted=6.522484409, expected=355
# predicted=17.13603232, expected=0
# predicted=482.9333744, expected=0
# predicted=1315.933714, expected=1046
# predicted=2288.447209, expected=299
# predicted=2302.013496, expected=2261
# predicted=675.6438241, expected=2948
# predicted=6.513251203, expected=435
# predicted=17.11176919, expected=10
# predicted=482.2496597, expected=0
# predicted=1314.070697, expected=1193
# predicted=2285.207354, expected=236
# predicted=2298.754428, expected=3665
# predicted=674.687289 , expected=2924
# predicted=6.504029166, expected=667
# predicted=17.08754164, expected=45
# predicted=481.5669143, expected=79
# predicted=1312.210279, expected=290
# predicted=2281.972038, expected=4664
# predicted=2295.499942, expected=6535
# predicted=673.7320911, expected=5093
# predicted=6.49481911 , expected=452
# predicted=17.06335077, expected=0
# predicted=480.8851345, expected=14
# predicted=1310.35252 , expected=629
# predicted=2278.741339, expected=731
# predicted=2292.250088, expected=1654
# predicted=672.7782551, expected=5
# predicted=6.485623821, expected=357
# predicted=17.03919428, expected=11
# predicted=480.2043184, expected=0
# predicted=1308.497373, expected=805
# predicted=2275.51519 , expected=252
# predicted=2289.004815, expected=3897
# predicted=671.8257616, expected=4289
# predicted=6.476442195, expected=400
# predicted=17.0150714 , expected=20
# predicted=479.5244659, expected=0
# predicted=1306.644867, expected=1460
# predicted=2272.293626, expected=275
# predicted=2285.76415 , expected=34
# predicted=670.8746233, expected=281
# predicted=6.467273862, expected=772
# predicted=16.9909818 , expected=6
# predicted=478.8455764, expected=8
# predicted=1304.794974, expected=945
# predicted=2269.076608, expected=3542
# predicted=2282.528063, expected=6003
# predicted=669.9248276, expected=5274
# predicted=6.458117797, expected=682
# predicted=16.96692635, expected=0
# predicted=478.1676485, expected=0
# predicted=1302.947707, expected=894
# predicted=2265.864155, expected=953
# predicted=2279.296565, expected=1158
# predicted=668.9763798, expected=1355
# predicted=6.448974488, expected=938
# predicted=16.94290521, expected=26
# predicted=477.4906805, expected=0
# predicted=1301.10305 , expected=1027
# predicted=2262.656243, expected=521
# predicted=2276.069638, expected=2143
# predicted=668.029272 , expected=46
# predicted=6.439844056, expected=378
# predicted=16.91891839, expected=6
# predicted=476.8146707, expected=4
# predicted=1299.261008, expected=731
# predicted=2259.452879, expected=214
# predicted=2272.847282, expected=1774
# predicted=667.0835067, expected=4422
# predicted=6.430726837, expected=1395
# predicted=16.89496548, expected=133
# predicted=476.1396178, expected=47
# predicted=1297.421572, expected=1054
# predicted=2256.254045, expected=3644
# predicted=2269.629486, expected=4266
# predicted=666.1390792, expected=5172
# predicted=6.421622587, expected=473
# predicted=16.87104638, expected=0
# predicted=475.4655206, expected=5
# predicted=1295.584741, expected=764
# predicted=2253.059743, expected=3856
# predicted=2266.416247, expected=1391
# predicted=665.1959898, expected=53
# predicted=6.412531236, expected=360
# predicted=16.84716103, expected=2
# predicted=474.7923778, expected=39
# predicted=1293.75051 , expected=490
# predicted=2249.869961, expected=1001
# predicted=2263.207556, expected=2511
# predicted=664.2542349, expected=2404
# predicted=6.403452642, expected=1689
# predicted=16.82330953, expected=0
# predicted=474.1201881, expected=66
# predicted=1291.918877, expected=980
# predicted=2246.684697, expected=829
# predicted=2260.003409, expected=13
# predicted=663.3138138, expected=663
# predicted=6.394386887, expected=1157
# predicted=16.79949184, expected=58
# predicted=473.4489501, expected=22
# predicted=1290.089835, expected=913
# predicted=2243.503941, expected=439
# predicted=2256.803797, expected=3115
# predicted=662.3747237, expected=5676
# predicted=6.385333968, expected=322
# predicted=16.7757079 , expected=0
# predicted=472.7786623, expected=57
# predicted=1288.263384, expected=898
# predicted=2240.327689, expected=1972
# predicted=2253.608716, expected=5056
# predicted=661.4369634, expected=4787
# predicted=6.37629391 , expected=746
# predicted=16.75195762, expected=26
# predicted=472.1093235, expected=9
# predicted=1286.439519, expected=365
# predicted=2237.155933, expected=1842
# predicted=2250.418157, expected=2415
# predicted=660.5005306, expected=1943
# predicted=6.367266653, expected=0
# predicted=16.72824095, expected=0
# predicted=471.4409323, expected=9
# predicted=1284.618235, expected=1005
# predicted=2233.988669, expected=2735
# predicted=2247.232116, expected=6074
# predicted=659.5654236, expected=5413
# predicted=6.358252174, expected=1409
# predicted=16.70455785, expected=0
# predicted=470.7734873, expected=146
# predicted=1282.79953 , expected=3381
# predicted=2230.825888, expected=1316
# predicted=2244.050586, expected=38
# predicted=658.6316404, expected=7
# predicted=6.34925044 , expected=0
# predicted=16.68090828, expected=0
# predicted=470.1069874, expected=0
# predicted=1280.983401, expected=0
# predicted=2227.667585, expected=0
# predicted=2240.87356 , expected=0
# predicted=657.6991794, expected=16
# predicted=6.340261451, expected=41

# %%
title = titleTest
ylabel='parts per million'
xlabel=''

ax = test[field].plot(legend=True,figsize=(20,6),title=title)
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test[field], predictions)
print(titleTest + f' MSE Error: {error:11.10}')
# Out:
# Arima((5, 0, 2)) - ((2, 0, 2, 7)) MSE Error: 2175364.448

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test[field], predictions)
print(titleTest + f' SARIMA(0,1,3)(1,0,1,12) RMSE Error: {error:11.10}')
# Out:
# Arima((5, 0, 2)) - ((2, 0, 2, 7)) SARIMA(0,1,3)(1,0,1,12) RMSE Error: 1474.911675

# %%
model = SARIMAX(df[field],order=arima_order,seasonal_order=arima_seasonal_order)
results = model.fit()
fcast = results.predict(len(df),len(df)+11,typ='levels').rename('SARIMA '+ titleTest + ' Forecast')

# %%
ax = df[field].plot(legend=True,figsize=(22,6),title=title)
fcast.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);
